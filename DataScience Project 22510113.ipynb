# %% [markdown]
# ## Loan Approval project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_approval_dataset.csv');

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.dtypes
# Out:
# loan_id                       int64
#  no_of_dependents             int64
#  education                   object
#  self_employed               object
#  income_annum                 int64
#  loan_amount                  int64
#  loan_term                    int64
#  cibil_score                  int64
#  residential_assets_value     int64
#  commercial_assets_value      int64
#  luxury_assets_value          int64
#  bank_asset_value             int64
#  loan_status                 object
# dtype: object

# %%
x = df.drop(' loan_status',axis = 1)
y = df[' loan_status']

# %%
sns.countplot(x=df[' education'])
# Out:
# <Axes: xlabel=' education', ylabel='count'>

# %%
sns.countplot(x=df[' self_employed'])
# Out:
# <Axes: xlabel=' self_employed', ylabel='count'>

# %%
## Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
x[' education'] = le.fit_transform(x[' education'])
x[' self_employed'] = le.fit_transform(x[' self_employed'])
x[' cibil_score'] = le.fit_transform(x[' cibil_score'])

# %%
x.dtypes
# Out:
# loan_id                      int64
#  no_of_dependents            int64
#  education                   int32
#  self_employed               int32
#  income_annum                int64
#  loan_amount                 int64
#  loan_term                   int64
#  cibil_score                 int64
#  residential_assets_value    int64
#  commercial_assets_value     int64
#  luxury_assets_value         int64
#  bank_asset_value            int64
# dtype: object

# %%
x.head()
# Out:
#    loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0        1                  2           0               0        9600000
# 1        2                  0           1               1        4100000
# 2        3                  3           0               0        9100000
# 3        4                  3           0               0        8200000
# 4        5                  5           1               1        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           478                    2400000
# 1      12200000           8           117                    2700000
# 2      29700000          20           206                    7100000
# 3      30700000           8           167                   18200000
# 4      24200000          20            82                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value
# ...

# %%
le.classes_
# Out:
# array([300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312,
#        313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325,
#        326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338,
#        339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351,
#        352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364,
#        365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377,
#        378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390,
#        391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403,
#        404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416,
#        417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429,
#        430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442,
#        443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455,
#        456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468,
# ...

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel=' loan_status', ylabel='count'>

# %%
y.value_counts()
# Out:
#  loan_status
#  Approved    2656
#  Rejected    1613
# Name: count, dtype: int64

# %%
sns.jointplot(x=' cibil_score', y=' income_annum', data = df,hue=' loan_status')

# %%
one = df.iloc[:,0:4]
one[' loan_status'] = y

two = df.iloc[:,4:8]
two[' loan_status'] = y

three = df.iloc[:,8:12]
three[' loan_status'] = y

# %%
sns.pairplot(one, hue=' loan_status')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(two, hue=' loan_status')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(three, hue=' loan_status')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = df[[' income_annum',' loan_amount', ' cibil_score']]
x_scaled = scaler.fit_transform(x)
x_scaled.ndim
type(x_scaled)
# Out:
# numpy.ndarray

# %%
### Outlier detection and removal

# %%
from sklearn.ensemble import IsolationForest

# %%
iso = IsolationForest(contamination = 0.05, random_state = 0)

# %%
x_encoded = x.apply(le.fit_transform)
clean = iso.fit_predict(x_encoded,y)

# %%
x_clean = x[clean==1]
y_clean = y[clean==1]

# %%
x_clean.shape, y_clean.shape
# Out:
# ((4055, 3), (4055,))

# %%
## Feature selection

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
skf = SelectKBest(k=3, score_func = chi2)

# %%
skf.fit_transform(x_clean,y_clean)
# Out:
# array([[ 9600000, 29900000,      778],
#        [ 4100000, 12200000,      417],
#        [ 9100000, 29700000,      506],
#        ...,
#        [ 6500000, 23900000,      457],
#        [ 4100000, 12800000,      780],
#        [ 9200000, 29700000,      607]], dtype=int64)

# %%
skf.get_support()
# Out:
# array([ True,  True,  True])

# %%
x_clean = x_clean.iloc[:, skf.get_support()]

# %%
x_clean = x_clean.iloc[:, skf.get_support()]

# %%
x_clean
# Out:
#        income_annum   loan_amount   cibil_score
# 0           9600000      29900000           778
# 1           4100000      12200000           417
# 2           9100000      29700000           506
# 3           8200000      30700000           467
# 4           9800000      24200000           382
# ...             ...           ...           ...
# 4264        1000000       2300000           317
# 4265        3300000      11300000           559
# 4266        6500000      23900000           457
# 4267        4100000      12800000           780
# 4268        9200000      29700000           607
#
# [4055 rows x 3 columns]

# %%
### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x_clean)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                  0            1            2
# count  4055.000000  4055.000000  4055.000000
# mean      0.494838     0.398228     0.501012
# std       0.277001     0.234090     0.282183
# min       0.000000     0.000000     0.000000
# 25%       0.257732     0.203343     0.261667
# 50%       0.494845     0.387187     0.501667
# 75%       0.731959     0.568245     0.740833
# max       1.000000     1.000000     1.000000

# %%
## Cross-Validation

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x_scaled,y_clean,random_state=0)

# %%
x_train.shape
# Out:
# (3041, 3)

# %%
x_test.shape
# Out:
# (1014, 3)

# %%
## Build the model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state = 0)

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9201183431952663

# %%
x_train.shape
# Out:
# (3041, 3)

# %%
new = [[9600000,900000,550]]

# %%
sc = MinMaxScaler()
sc.fit_transform(x_train)
# Out:
# array([[0.91752577, 0.8551532 , 0.34666667],
#        [0.18556701, 0.12534819, 0.96      ],
#        [0.40206186, 0.33983287, 0.275     ],
#        ...,
#        [0.09278351, 0.05571031, 0.505     ],
#        [0.27835052, 0.23398329, 0.87833333],
#        [0.22680412, 0.19498607, 0.91833333]])

# %%
clf.predict(scaler.transform(new))[0]
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ' Approved'
